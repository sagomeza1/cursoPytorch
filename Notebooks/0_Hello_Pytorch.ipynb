# %% [markdown]
# ![banner (1).png](data:image/png;base64,...)

# %% [markdown]
# En esta clase nos introduciremos en la magia de PyTorch, un popular y ampliamente utilizado framework de machine learning de código abierto.
#
# Permite construir y entrenar modelos de deep learning con facilidad. Si quieres ser un profesional de la IA, aprender PyTorch es esencial.

# %% [markdown]
# Con PyTorch puedes aprovechar los últimos avances en inteligencia artificial para crear soluciones innovadoras para una amplia gama de aplicaciones, desde visión por computadora hasta procesamiento de lenguaje natural y más.
#
# También cuenta con el respaldo de una comunidad vibrante y solidaria de desarrolladores e investigadores. Esto significa que tendrás acceso a una gran cantidad de recursos, herramientas y conocimientos que lo ayudarán a mantenerse a la vanguardia de la investigación y el desarrollo de IA.
#
# Podrás apreciar cómo se ve un modelo relativamente sencillo. Sin embargo, esta siempre será la estructura de un modelo, no importa que sea de visión, transformers para procesamiento de lenguaje natural o reinforcement learning.
#
# Debajo de todo eso, por más complicado que suene, hay un modelo de este tipo. Y es lo que marca la creación del **machine learning moderno.**

# %% [markdown]
# En PyTorch, `nn.Module` es muy importante. Es una clase que te permite crear, almacenar y manipular todo tipo de capas y operaciones de redes neuronales.
#
# ¿Por qué es esto genial? Significa que puedes crear modelos complejos con muchas capas sin tener que preocuparte por los detalles de cada una de ellas. `nn.Module` se encarga de todo eso por ti, para que puedas centrarte en construir tu modelo y obtener resultados.
#
# En resumen, si estás trabajando con PyTorch y construyendo redes neuronales, `nn.Module` será tu nuevo mejor amigo.

# %%
import torch
import torch.nn as nn

class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, num_layers=2, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, text):
        embedded = self.embedding(text)
        output, (hidden, cell) = self.rnn(embedded)
        final_hidden = hidden[-1]
        return self.fc(final_hidden)
    ...
# Out:
# c:\Users\User\Documents\Cursos Platzi\Redes Neuronales con PyTorch\venv\Lib\site-packages\torch\_subclasses\functional_tensor.py:276: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:81.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %% [markdown]
# **Veamos este código paso a paso:**
#
# 1. Definimos una clase llamada **`TextClassifier`** que se hereda de **`nn.Module`**.
# 2. En el constructor definimos las capas de nuestro modelo: una capa embedding, una capa LSTM con 2 capas y **`hidden_dim`** unidades ocultas por capa, y una capa lineal que asigna el estado oculto final a la salida dimensión.
# 3. Con el método **`forward`** primero creamos un embedding con el texto de entrada usando la capa de embedding.
# 4. Luego pasamos el texto embedido a través de la capa LSTM y recuperamos el estado oculto final.
# 5. Finalmente, pasamos el estado oculto final a través de la capa lineal para obtener los logits de salida.
#
# Para usar este modelo puedes instanciarlo así:

# %%
vocal_size = 10_000
embedding_dim = 100
hidden_dim = 256
output_dim = 2 

model = TextClassifier(
    vocab_size=vocal_size,
    embedding_dim=embedding_dim,
    hidden_dim=hidden_dim,
    output_dim=output_dim
)

# %%
model
# Out:
# TextClassifier(
#   (embedding): Embedding(10000, 100)
#   (rnn): LSTM(100, 256, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=256, out_features=2, bias=True)
# )

# %% [markdown]
# Aquí, asumimos que estamos haciendo una clasificación binaria, por lo que `output_dim` se establece en 2. Si estás haciendo una clasificación de varias clases, debes configurar `output_dim` en el número de clases.
#
# Ten en cuenta que deberás definir tu propia canalización de preprocesamiento de texto y esquema de tokenización antes de poder entrenar este modelo en su conjunto de datos.

# %% [markdown]
# ## Conclusión

# %% [markdown]
# ¡Felicidades! Acabas de crear tu primer modelo PyTorch.
#
# A medida que avancemos en nuestro curso, profundizaremos en el mundo de PyTorch y exploraremos modelos más complejos. En la siguiente sección aprenderemos sobre los tensores, los bloques de construcción fundamentales de PyTorch.
